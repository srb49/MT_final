# %% [markdown]
# with modifications in some features
# // for csv-2

# %%
import pandas as pd
import spacy
nlp = spacy.load("en_core_web_lg")
import statistics
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
import collections
from collections import Counter
import re
import language_tool_python  
from nltk.tokenize import sent_tokenize
import textstat
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import math
from nltk.sentiment import SentimentIntensityAnalyzer
import language_tool_python
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
data_1 = pd.read_csv('../../csv/human/csv_human-2.csv')

# %%
data_1

# %%
#data_prev = pd.read_csv('../csv/gpt/csv_gpt3-1.csv')
data_prev = pd.read_csv('../csv/human/csv_human-1.csv')
#data_new=data_prev[['essay', 'topic']].copy()
#data_new=data_prev.iloc[:10, :2].copy()
data=data_prev.iloc[101:151, :2].copy()

# %%
data

# %%
def add_feature(df, column_index, feature):
    # Get the column names
    columns = df.columns.tolist()

    # Insert the new feature at the specified index
    columns.insert(column_index, feature)

    # Reindex the dataframe with the updated column order
    df = df.reindex(columns=columns)

    return df

def walk_tree1(node, depth):
    if node.n_lefts + node.n_rights > 0:
        dep=[]
        d=0
        for child in node.children:
            d=walk_tree1(child, depth + 1)
            dep.append(d)
        return max(dep)
    
    else:
        return depth
    
def avg_sentence_complexity(str1):
    final_list=[]
    nlp = spacy.load("en_core_web_lg")
    temp_list=[]
    sents=[]
    txt = str1
    txt=" ".join(txt.split())
    text = nlp(txt)
    sent_tokenize1 = (list(text.sents))
    sents.append(sent_tokenize1[0])
    for sent in text.sents:
        d=walk_tree1(sent.root, 0)
        temp_list.append(d)
            #displacy.render(sent, style="dep")
        final_list.append(temp_list)
        #print("essay first line ",sents[len(sents)-1],"max is ",max(temp_list)," min is ",min(temp_list)," mean is ", round(statistics.mean(temp_list),3),
        #  " median is ",statistics.median(temp_list)," mode is ",statistics.mode(temp_list))
    return round(statistics.mean(temp_list),3)

def grammar_check(text):
    tool_gb = language_tool_python.LanguageTool('en-GB')

    substr1 = "is American English"
    substr2 = "British English"
    substr3 = "Consider shortening"
    
    matches = tool_gb.check(text)
    cnt=0
    for match in matches:
        if substr1 in match.message or substr2 in match.message or substr3 in match.message:
            print("***********this the US case/case to ignore****************")
            print(match)
            continue
        
        else:
            cnt+=1
            print("***********this other cases****************")
            print(match)
            
    print("total count ",cnt)
    return(cnt)

def generate_ngrams(s, n):
    # Convert to lowercases
    s = s.lower()
    
    # Replace all none alphanumeric characters with spaces
    s = re.sub(r'[^a-zA-Z0-9\s]', ' ', s)
    
    # Break sentence in the token, remove empty tokens
    tokens = [token for token in s.split(" ") if token != ""]
    
    # Use the zip function to help us generate n-grams
    # Concatentate the tokens into ngrams and return
    ngrams = zip(*[tokens[i:] for i in range(n)])
    list1=[" ".join(ngram) for ngram in ngrams]
    #return [" ".join(ngram) for ngram in ngrams]
    return list1

def rep_count(str1):
    tot_rp=[]
    max_rp=[]
    #print(ess[i],"\n","new","\n")
    list1=generate_ngrams(str1, 5)
    myset = set(list1)
    rept = len(list1) - len(myset)
    tot_rp.append(rept)
    c = collections.Counter(list1)
    c.most_common(1)[0][1]
    max_rp.append(c.most_common(1)[0][1])
    #print("\n\nnew essay index ",i,": for essay ",list1[0],":")
    #print("repeat ",rept," times | most common phrase is **",c.most_common(1)[0][0], "** |number of repeataion happened: ",c.most_common(1)[0][1]," times\n")
    #print("\ncommon phrases: \n",c)
    #print("\nmy set: \n",myset)
    #print("list ",tot_rp," ",max_rp)
    #print("individual ",rept," ",c.most_common(1)[0][1])
    return rept,c.most_common(1)[0][1],c.most_common(10)

def most_frequent(str1):

    nlp = spacy.load("en_core_web_lg")
    str1=" ".join(str1.split())
    text = nlp(str1)
    words = [token.text for token in text if token.is_stop!= True and token.is_punct!= True]
    w_c=Counter(words)
    m_f=w_c.most_common(1)[0][1]
    m_f_r=m_f/len(words)
    return m_f,m_f_r


def pos1(str1):

    nlp = spacy.load("en_core_web_lg")
    str1=" ".join(str1.split())
    text = nlp(str1)
    
    
    tags=[]
    for w in text:
        tags.append(w.pos_)
    tag_freq = Counter(tags)
    #print ("=====tag FREQUENCY=====")
    #print(tag_freq.values())
    n=0
    v=0
    a=0
    p=0
    
    w_l=word_cnt(str1)
    for key in tag_freq:
        #print("hi")
        if key=='NOUN':
            n=tag_freq[key]/w_l
            #print("n ",n)
        elif key == 'VERB':
            v=tag_freq[key]/w_l
            #print("v ",v)
        elif key =='ADJ':
            a=tag_freq[key]/w_l
            #print("a ",a)
        elif key =='PRON':
            p=tag_freq[key]/w_l

        #elif key=='MD':

            #print("the number of modal verbs ",key, tag_freq.values())
            #print("p ",p)
        #print("key is ",key," value ",tag_freq[key], " frequency ", tag_freq[key]/w_l)
    return n,v,a,p

def uniq_w(str1):
    return len(set(str1.split()))

def stop_w(str1):
    nlp = spacy.load("en_core_web_lg")
    text = nlp(str1)
    words = [token.text for token in text if token.is_stop == True]
    #print(words)
    return(len(words))

def stop_w_r(str1):
    number_of_sentences = sent_tokenize(str1)
    n=len(number_of_sentences)

    nlp = spacy.load("en_core_web_lg")
    text = nlp(str1)
    words = [token.text for token in text if token.is_stop == True]
    #print(words)
    
    l=len(words)
    swr=l/n
    return swr

def sen_len(str1):
    number_of_sentences = sent_tokenize(str1)
    i=0
    avg=0
    sl=[]
    for num in number_of_sentences:
        i+=1
        words=num.split()
        avg+=len(words)
        sl.append(len(words))
    #print(num, len(num),len(words))
    avg=avg/i
    md=statistics.mode(sl)
    mx=max(sl)
    mn=min(sl)
    return avg,md,mx,mn

def sen_num(str1):
    number_of_sentences = sent_tokenize(str1)
    n=len(number_of_sentences)
    #print(n)
    return n

def word_cnt(str1):
    words=str1.split()
    return len(words)

def lexical_diversity(str1):
    tokens = word_tokenize(str1)

    lex_div = len(set(tokens)) / len(tokens)
    return lex_div

def discourse_conn(str1):
    tokens = nltk.word_tokenize(str1)

    # Perform part-of-speech tagging
    pos_tags = nltk.pos_tag(tokens)

    # Identify discourse connectors based on part-of-speech patterns
    discourse_connectors = [token for token, pos in pos_tags if pos in ['CC', 'RB', 'IN']]

    # Output the identified discourse connectors
    #print("Discourse connectors:", discourse_connectors)
    #print("Discourse connector count:", len(discourse_connectors))
    return len(discourse_connectors)

def sentence_similarity(str1):
    text = nlp(str1)
    sent_tokenize = (list(text.sents))
    i=0
    sensim=0.0
    sensim_list=[]
    for sent2 in sent_tokenize:
        i+=1
        if i == 1:
            sent1=sent2
            continue
        #print (sent2.similarity(sent1))
        sensim+=sent2.similarity(sent1)
        sensim_score=sent2.similarity(sent1)
        sent1=sent2
        sensim_list.append(sensim_score)
    sensim=sensim/i
    #print("average sentence similarity is ",sensim)

    return sensim,sensim_list

def word_similarity(str1):
    text = nlp(str1)
    p=0
    ps=0
    n=0
    ns=0
    total=0
    word = [token.text for token in text if token.is_punct != True]
    for i in range(len(word)):
    #x.append(i)
    #print(i)
    #print(words[i])
        w2=word[i]
        if i == 0:
            w1=w2
            continue
    #print (nlp(w2).similarity(nlp(w1)))
        #print(w1+ " "+w2+" ",nlp(w2).similarity(nlp(w1)))
        if nlp(w2).similarity(nlp(w1))>0:
            p=p+1
            ps+=nlp(w2).similarity(nlp(w1))
        elif nlp(w2).similarity(nlp(w1))<0:
            n=n+1
            ns+=nlp(w2).similarity(nlp(w1))
    #y1=y1+float(nlp(w2).similarity(nlp(w1)))
    #print(y1)
    #y.append(y1)
        total+=nlp(w2).similarity(nlp(w1))
        w1=w2
    #print(p,n)
    return p,n,total,ps,ns

def get_modal_verbs(text):
    #nlp = spacy.load('en_core_web_sm')
    doc = nlp(text)
    cnt=0
    modal_verbs = []
    for token in doc:
        if token.pos_ == 'VERB' and token.tag_ == 'MD':
            modal_verbs.append(token.lemma_)
            cnt+=1
    w_l=word_cnt(text)
    cnt_rate=cnt/w_l

    return cnt_rate,modal_verbs

def calculate_readability(text):
    # Calculate the Flesch-Kincaid Grade Level
    flesch_grade = textstat.flesch_kincaid_grade(text)

    # Calculate the Automated Readability Index (ARI)
    ari = textstat.automated_readability_index(text)

    # Calculate the Coleman-Liau Index
    coleman_liau = textstat.coleman_liau_index(text)

    # Return the readability scores
    return flesch_grade, ari, coleman_liau

def calculate_cohesion(text):
    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove stopwords and punctuation
    stop_words = set(stopwords.words("english"))
    tokens = [token.lower() for token in tokens if token.isalnum() and token.lower() not in stop_words]

    # Lemmatize the tokens
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(token) for token in tokens]

    # Convert generator to a list of bigrams
    bigrams = list(nltk.bigrams(tokens))

    # Calculate bigram frequencies
    bigram_freq = Counter(bigrams)

    # Calculate pointwise mutual information (PMI) for bigrams
    total_bigrams = len(bigrams)
    pmi_scores = {}
    for bigram, freq in bigram_freq.items():
        pmi = math.log(freq / total_bigrams / ((tokens.count(bigram[0]) / len(tokens)) * (tokens.count(bigram[1]) / len(tokens))))
        pmi_scores[bigram] = pmi

    # Calculate average PMI as a measure of cohesion
    avg_pmi = sum(pmi_scores.values()) / len(pmi_scores)

    return avg_pmi

def calculate_uniqueness_score(text):
    # Tokenize the text into words
    words = word_tokenize(text)

    # Calculate the frequency distribution of words
    word_freq = Counter(words)

    # Calculate the uniqueness score as the ratio of unique words to total words
    uniqueness_score = len(word_freq) / len(words)

    return uniqueness_score

def detect_emotional_tone(text):
    sid = SentimentIntensityAnalyzer()
    sentiment_scores = sid.polarity_scores(text)
    return sentiment_scores

def para_cnt(str1):
    paragraphs = str1.split("\n\n")
    return len(paragraphs)

def discourse_marker():
    with open('../other/da.txt',"r") as file:
        text=file.read()
    d_list = text.split(",")
    #print(d_list)
    d_list.remove('')
    #index = d_list.index('')
    #print(index)
    #d_list.remove('')
    return d_list

def discourse_marker_check(essay):
    d_list=discourse_marker()
    count=0
    for marker in d_list:
        occurrences = re.findall(r'\b' + re.escape(marker) + r'\b', essay, flags=re.IGNORECASE)
        count += len(occurrences)
        #print("occurances ",occurrences," for marker ",marker)
    #print("count ",count)
    return count

# %%
ess=data.loc[:,'essay']
#for i in range(len(ess)):
for i in range(101,150):
    pc=para_cnt(ess[i])
    data.loc[i,'para_count']=pc
    #print(pc)

    wc=word_cnt(ess[i])
    data.loc[i,'word_count']=wc
    #print(wc)

    ns=sen_num(ess[i])
    data.loc[i,'sentence_count']=ns

    avg,md,mx,mn=sen_len(ess[i])
    data.loc[i,'sentence_len(mean)']=avg
    #data.loc[i,'sentence_len(mode)']=md
    data.loc[i,'sentence_len(max)']=mx
    data.loc[i,'sentence_len(min)']=mn

    #sw=stop_w(ess[i])
    swr=stop_w_r(ess[i])
    #data.loc[i,'stop_words']=sw
    data.loc[i,'sw_rates']=swr

    uw=uniq_w(ess[i])
    data.loc[i,'unique_words']=uw

    uniq = calculate_uniqueness_score(ess[i])
    data.loc[i,'unique_words_rates']=uniq
    

    #uw=uniq_w(ess[i])
    n,v,a,p=pos1(ess[i])
    mvc,mv=get_modal_verbs(ess[i])
    data.loc[i,'noun']=n
    data.loc[i,'verb']=v
    data.loc[i,'adj']=a
    data.loc[i,'pron']=p
    data.loc[i,'modal verb']=mvc

    #print("n,v,a,p,modal",n,v,p,mvc)

    

    mf,mfr=most_frequent(ess[i])
    data.loc[i,'occurrance_of_most_freq_word']=mf
    data.loc[i,'rate_of_occurrance']=mfr

    

    tr,mr,rep_list=rep_count(ess[i])
    data.loc[i,'number_of_repeatation']=tr
    data.loc[i,'max_occurance_of_most_frequent_phrase']=mr

    

    asc=avg_sentence_complexity(ess[i])
    data.loc[i,'avg sentence complexity']=asc

    l_d=lexical_diversity(ess[i])
    data.loc[i,'lexical diversity']=l_d

    sensim,sensim_list=sentence_similarity(ess[i])
    sensim_list.sort()
    sensim_mod=statistics.mode(sensim_list)
    sensim_med=statistics.median(sensim_list)
    #data.loc[i,'sentence similarity mean']=sensim
    #data.loc[i,'sentence similarity median']=sensim_med
    #data.loc[i,'sentence similarity mode']=sensim_mod

    pos,neg,tot,p_s,n_s=word_similarity(ess[i])
    data.loc[i,'word_sim_p_count']=pos
    data.loc[i,'word_sim_p_score']=p_s
    data.loc[i,'word_sim_n_count']=neg
    data.loc[i,'word_sim_n_score']=n_s
    data.loc[i,'word_sim_score']=tot

    f_g, ari, c_l = calculate_readability(ess[i])
    data.loc[i,'flesch grade']=f_g
    data.loc[i,'Automated Readability']=ari
    data.loc[i,'coleman_liau']=c_l

    coh_score=calculate_cohesion(ess[i])
    data.loc[i,'cohesion score']=coh_score

    emot = detect_emotional_tone(ess[i])
    data.loc[i,'positive_sentiment']=emot['pos']
    data.loc[i,'negative_sentiment']=emot['neg']
    data.loc[i,'neutral_sentiment']=emot['neu']

    cnt=discourse_marker_check(ess[i])
    data.loc[i,'discourse_marker']=cnt

    print(i)
    data.loc[i,'grammar']=grammar_check(ess[i])

    data.loc[i,'label']=0

print(f"The number of columns in the CSV file is: {data.shape[1]}")
# Out:
# /tmp/ipykernel_2595074/1315274346.py:264: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   if nlp(w2).similarity(nlp(w1))>0:
# /tmp/ipykernel_2595074/1315274346.py:267: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   elif nlp(w2).similarity(nlp(w1))<0:
# /tmp/ipykernel_2595074/1315274346.py:273: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   total+=nlp(w2).similarity(nlp(w1))
# 101
# total count  0
# /tmp/ipykernel_2595074/1315274346.py:264: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   if nlp(w2).similarity(nlp(w1))>0:
# /tmp/ipykernel_2595074/1315274346.py:267: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   elif nlp(w2).similarity(nlp(w1))<0:
# /tmp/ipykernel_2595074/1315274346.py:273: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   total+=nlp(w2).similarity(nlp(w1))
# 102
# total count  0
# 103
# total count  0
# 104
# ***********this other cases****************
# Offset 1041, length 7, Rule ID: YOUTUBE
# Message: The official name of this popular video platform is spelled with a capital “T”.
# Suggestion: YouTube
# ...ideos featuring gory fighting scenes on Youtube could easily make a child believe those...
#                                            ^^^^^^^
# ***********this other cases****************
# Offset 1262, length 14, Rule ID: MANY_NN
# Message: Possible agreement error. The noun ‘action’ seems to be countable; consider using: “several actions”.
# Suggestion: several actions
# ...ence, parents and institutions can take several action. Firstly, it should be ensured that no ...
#                                            ^^^^^^^^^^^^^^
# ***********this other cases****************
# Offset 1333, length 9, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# ...uld be ensured that no social evils and disaccord exist within the households. If childre...
#                                            ^^^^^^^^^
# ***********this other cases****************
# Offset 1573, length 8, Rule ID: SO_AS_TO
# Message: ‘So as to’ expresses purpose and is used in formal texts. Consider using “to”
# Suggestion: to
# ...hat their children view on social media so as to minimize the latter's exposure to harmf...
#                                            ^^^^^^^^
# ***********this the US case/case to ignore****************
# Offset 1651, length 9, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘behaviors’ is American English.
# Suggestion: behaviours
# ...e to harmful contents that fuel violent behaviors. Moreover, it is of importance that sch...
#                                            ^^^^^^^^^
# total count  4
# 105
# ***********this other cases****************
# Offset 280, length 5, Rule ID: MD_BASEFORM
# Message: The modal verb ‘could’ requires the verb’s base form.
# Suggestion: lead
# ...uch time on technological devices could leads to physical health problems and this tr...
#                                            ^^^^^
# ***********this other cases****************
# Offset 710, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Put a space after the comma.
# Suggestion: , .
# ...online classes, write reports and emails,... As a result, people might suffer from...
#                                            ^^
# total count  2
# 106
# ***********this the US case/case to ignore****************
# Offset 820, length 9, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘travelers’ is American English.
# Suggestion: travellers
# ... festivals, which attract a plethora of travelers nationwide and worldwide, are celebrate...
#                                            ^^^^^^^^^
# total count  0
# 107
# total count  0
# 108
# ***********this the US case/case to ignore****************
# Offset 9, length 7, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘centers’ is American English.
# Suggestion: centres
# Shopping centers have been increasing in popularity over...
#          ^^^^^^^
# ***********this other cases****************
# Offset 462, length 11, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: jewellers; jewelleriser; jewellerisers
# ... range of products, such as clothes and jewelleries, from both local and international bran...
#                                            ^^^^^^^^^^^
# ***********this the US case/case to ignore****************
# Offset 627, length 6, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘center’ is American English.
# Suggestion: centre
# ...rts footwear from the Nike brand in the center. They can try wearing shoes and get adv...
#                                            ^^^^^^
# ***********this other cases****************
# Offset 865, length 3, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: CAF; can; car; cap; cat; cab; cafe; café; AF; CAA; calf; cam; CAC; CSF; cal; CBF; CMF; CTF; CPF; GAF; cad; oaf; caw; RAF; AAF; BAF; CA; CAB; CAD; CAG; CAH; CAI; CAJ; CAK; CAL; CAN; CAQ; CARF; CAS; CAT; CAU; CAV; CAW; CAY; CCF; CDF; CEF; CF; CFF; CGF; CHF; CIF; CJF; CNF; COF; CQF; CRF; CUF; CVF; CWF; CZF; Ca; Cal; Cam; Car; Cf; DAF; FAF; IAF; JAF; MAF; NAF; PAF; SAF; TAF; Taf; XAF; ZAF; ca; caff; cay; cf; CAE; a; of; was; as; at; an; had; has; day; if; may; off; came; half; law; man; way; San; act; call; care; cars; case; cast; cut; far; gas; pay; ran; saw; war; CD; am; bad; bar; camp; card; cm; coal; fan; lay; map; safe; say; tax; van; NCAA; ban; bay; cash; cave; clan; coat; craft; cup; eat; gap; hat; lap; leaf; raw; ray; sat; tag; AFC; CBC; CDs; CIA; CNN; CPU; Carl; Dan; MA; Max; Sam; WWF; bag; bat; calm; caps; cats; ear; fat; jaw; lab; oak; pan; rap; CH; CSS; CTV; Carr; IDF; Mac; RAAF; SAS; UHF; USAF; ace; aft; cage; cake; cane; cans; cape; cart; chat; chef; clad; clay; con; cop; cow; crab; cry; cue; dad; dam; deaf; gag; hay; mad; pad; par; ram; rat; ref; sad; scan; tan; tap; wax; CBA; CBN; CCC; CCD; CDC; CDU; CFB; CG; CGI; CIO; CNS; CPA; CPC; CPI; CPR; CRT; CSA; CSI; CSU; CSX; CV; Cain; Chad; HF; IMF; ITF; Kay; Mae; Mao; NAD; PAC; PDF; Raj; Taft; UA; cafes; cafés; carp; claw; cod; cuff; elf; fax; ham; jar; lag; ma; mat; pa; pas; raft; sac; sap; sax; scam; scar; scarf; ta; tab; tar; var; AAU; AIF; Alf; CBI; CCA; CCI; CCP; CCS; CDA; CDR; CEA; CFA; CFC; CFO; CFR; CFS; CIC; CIE; CLR; CMA; CME; CMG; CNC; CNG; CNR; CNT; CPM; CRC; CSC; CSL; CSP; CSR; CST; CTA; CTC; CVS; CWA; Cary; Cass; Cato; DAC; DAT; FAO; FAQ; IAS; IAU; ISAF; MF; MSF; NAC; NCA; NSF; OAS; Pam; RAC; RPF; Tam; Tao; Tay; UAV; UAW; UDF; USF; WAC; WAP; ah; cabs; cams; capo; cask; cha; chan; char; clam; clap; clef; col; crap; cub; cyan; fad; gal; lad; lax; loaf; nan; oar; pal; paw; rag; tau; vat; yam; yaw; AAT; AEF; AFM; AFN; ARF; BWF; CBM; CBP; CBT; CCG; CCR; CDO; CDT; CEP; CFD; CFE; CFP; CGA; CGS; CIT; CKD; CLI; CLP; CLS; CMB; CMU; CND; CNE; CPE; CPO; CSD; CSG; CSV; CTI; CTM; CTO; CTP; CTR; CVA; CVC; CVR; CVT; Cray; EAM; FAC; FCA; GDF; HCA; IAA; IAC; IAP; JAL; Jan; OSF; PSF; Ralf; SAA; SPF; TCA; UCA; cant; carb; cays; chaff; chap; coax; cob; cog; cot; cox; crag; cram; czar; gaff; hag; jab; kcal; lac; mar; nap; nay; oat; pat; sag; sf; tat; wan; yak; zag; CATV; CBO; CBR; CCB; CCU; CDN; CED; CFI; CFT; CFU; CJC; CJK; CLT; CNH; CNI; CRL; CTH; CVD; CWC; DAV; DCF; EHF; FAM; GAM; GCA; GEF; IAB; MCF; MDF; MLF; NAL; NFF; SMF; SNF; TCAS; UAR; VAC; VLF; WAAF; cl; coo; coy; cur; emf; jag; jay; maw; nag; pap; rad; scab; tac; wag; yah; ACAS; AFO; AFR; CDV; CJD; CLG; CSH; CTT; CXC; EAL; EOF; EPF; NaN; OAP; SHF; TEF; TTF; UAM; WFF; bah; chafe; cud; dab; daft; fay; gab; haft; nab; scad; tad; waif; yay; zap; CACM; CNAA; WRAF; baa; ciao; coif; cw; fas; hap; kif; naff; naif; raff; taw; waft; Vax; barf; cads; caws; craw; decaf; yap; AAA; CBS; CDP; CE; CEO; CHG; MCA; chm; cpl; da; jam; cpd; gay; oafs; oof; A; A1; A2; A3; A4; A5; AA; AAAF; AAB; AAC; AAD; AAE; AAG; AAH; AAI; AAJ; AAK; AAL; AAM; AAN; AAO; AAP; AAQ; AAR; AAS; AAV; AAW; AAX; AAY; AAZ; AB; ABF; AC; ACA; ACAE; ACAT; ACF; AD; ADF; AE; AFA; AFB; AFD; AFE; AFF; AFG; AFH; AFI; AFJ; AFK; AFL; AFQ; AFS; AFT; AFU; AFV; AFW; AFX; AFZ; AG; AGF; AHF; AI; AJ; AJF; AK; AKF; AL; AM; AMF; AN; ANF; AO; AOF; AP; APF; AQF; AR; ASF; AT; ATF; AU; AUF; AV; AVF; AX; AZ; AZF; Ab; Ac; Ag; Al; Ar; At; Au; BA; BAA; BAE; BAFA; BAFO; BAH; BAM; BAP; BAS; BAU; BAV; BAW; BAX; BAZ; BAe; BBF; BCA; BCAM; BCF; BCNF; BDF; BEF; BF; BFF; BGF; BHF; BIF; BKF; BLF; BMF; BNF; BOF; BPF; BRF; BSF; BTF; BUF; BVF; Ba; Bag; Bar; Bay; C; C0G; C10; C11; C12; C13; C14; C15; C16; C17; C18; C19; C20; C21; C22; C23; C24; C25; C27; C28; C2C; C30; C31; C32; C33; C34; C35; C36; C40; C41; C44; C45; C46; C47; C50; C51; C52; C53; C60; C61; C62; C63; C64; C65; C66; C69; C70; C77; C88; C91; C96; C99; CAAC; CADA; CADD; CAES; CAGR; CALR; CALT; CAMIF; CAMT; CAMY; CAPO; CAPV; CARM ...
# ...facilities, in particular, restaurants, caf shops and cinemas. Evidently, people ca...
#                                            ^^^
# ***********this the US case/case to ignore****************
# Offset 1146, length 4, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘cozy’ is American English.
# Suggestion: cosy
# ...in the shopping mall. People can have a cozy gathering there to taste specialities. ...
#                                            ^^^^
# total count  2
# 109
# ***********this other cases****************
# Offset 849, length 6, Rule ID: TIK_TOK
# Message: Did you mean “TikTok” (= social networking app)?
# Suggestion: TikTok
# ...ocial media platforms such as Facebook, Tiktok or Instagram that you can access to rea...
#                                            ^^^^^^
# total count  1
# 110
# ***********this other cases****************
# Offset 7, length 2, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: RO; to; or; go; no; so; do; pro; row; Rio; rod; Jo; ROC; RM; rob; rot; yo; RJ; ROK; roe; MRO; RPO; RU; fro; Ru; SRO; WO; bro; rt; ROM; Ron; Roy; AO; Aro; BO; BRO; Bo; CO; CRO; Co; DO; EO; ERO; FO; FRO; GO; HO; Io; JO; KO; Ko; LO; MO; Mo; NO; NRO; O; OO; Oro; PO; RC; RD; RE; RF; RGO; RI; RIO; RNO; ROA; ROI; ROL; ROR; ROS; ROT; ROV; RP; RS; RSO; RT; RTO; RV; RW; Ra; Rao; Rb; Rd; Rf; Rh; Ri; Rn; Roa; Rob; Row; Rs; Rt; SO; TO; UO; VO; ZO; ZRO; co; ho; lo; o; po; r; re; rho; RL; RQ; RX
# Trying ro do those things which are widely consid...
#        ^^
# ***********this other cases****************
# Offset 177, length 10, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: regardless
# ...hings and its consequences. To my mind, regaraless of all following consequences, taking r...
#                                            ^^^^^^^^^^
# ***********this other cases****************
# Offset 243, length 8, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: benefits
# ...g consequences, taking risks gives more benifirs than potential dangers.  On the one han...
#                                            ^^^^^^^^
# ***********this other cases****************
# Offset 292, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Put a space after the comma, but not before the comma.
# Suggestion: ,
# ...than potential dangers.  On the one hand , people seem to have a fear of the unkno...
#                                            ^^
# ***********this other cases****************
# Offset 460, length 8, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: property; poverty
# ... what they are possessing such as their proverty, their house or even their lives; There...
#                                            ^^^^^^^^
# ***********this other cases****************
# Offset 1470, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Don’t put a space before the full stop.
# Suggestion: .
# ...people with more benefits than drawbacks . It give opportunitiy for every individu...
#                                            ^^
# ***********this other cases****************
# Offset 1476, length 4, Rule ID: IT_VBZ
# Message: After ‘It’, use the third-person verb form “gives”.
# Suggestion: gives
# ... with more benefits than drawbacks . It give opportunitiy for every individuals to g...
#                                            ^^^^
# ***********this other cases****************
# Offset 1481, length 12, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: opportunity
# ... more benefits than drawbacks . It give opportunitiy for every individuals to gain new knowl...
#                                            ^^^^^^^^^^^^
# ***********this other cases****************
# Offset 1504, length 11, Rule ID: EVERY_EACH_SINGULAR
# Message: The noun should probably be in the singular form.
# Suggestion: individual
# ...wbacks . It give opportunitiy for every individuals to gain new knowledge, new experience.
#                                            ^^^^^^^^^^^
# total count  9
# 111
# ***********this other cases****************
# Offset 215, length 7, Rule ID: LC_AFTER_PERIOD
# Message: If a new sentence starts here, add a space and start with an uppercase letter.
# Suggestion:  Discuss;  discuss
# ...us on the present and future generation.discuss both views and show your opinion.  Peop...
#                                            ^^^^^^^
# ***********this other cases****************
# Offset 848, length 8, Rule ID: EVERYDAY_EVERY_DAY
# Message: ‘Everyday’ is an adjective. Did you mean “every day”?
# Suggestion: every day
# ... out that since the world is innovating everyday, everything that happened in the past m...
#                                            ^^^^^^^^
# ***********this other cases****************
# Offset 1248, length 7, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. Did you mean “labelled”, the past tense form of the verb ‘label’?
# Suggestion: labelled
# ...ch as how to deal with plagues that are labeled as incurable or how to tackle prolifera...
#                                            ^^^^^^^
# ***********this other cases****************
# Offset 1813, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Don’t put a space before the full stop.
# Suggestion: .
# ...oration and how to overcome difficulties . Hence, the younger generation can learn...
#                                            ^^
# ***********this the US case/case to ignore****************
# Offset 2120, length 7, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘instill’ is American English.
# Suggestion: instil
# ...llenges that they have gone through can instill the later generation with a sense of gr...
#                                            ^^^^^^^
# ***********this the US case/case to ignore****************
# Offset 2200, length 9, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘endeavors’ is American English.
# Suggestion: endeavours
# ...e of gratitude and appreciation for the endeavors and contributions of the ancestor.  In ...
#                                            ^^^^^^^^^
# total count  4
# 112
# ***********this the US case/case to ignore****************
# Offset 9, length 14, Rule ID: WHETHER
# Message: Consider shortening this phrase to just “whether”. It is correct though if you mean ‘regardless of whether’.
# Suggestion: whether
# Nowadays whether or not learning mathematics in school become a...
#          ^^^^^^^^^^^^^^
# ***********this other cases****************
# Offset 400, length 4, Rule ID: COMMA_COMPOUND_SENTENCE
# Message: Use a comma before ‘and’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , and
# ... that mathematics is no longer important and it should be removed as a school subjec...
#                                            ^^^^
# ***********this other cases****************
# Offset 551, length 4, Rule ID: COMMA_COMPOUND_SENTENCE
# Message: Use a comma before ‘and’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , and
# ...r tasks which required mathematics skill and it can run the operation very fast in i...
#                                            ^^^^
# ***********this other cases****************
# Offset 617, length 6, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Put a space after the comma.
# Suggestion: , there
# ...ion very fast in its system. For example,there are computer program like Microsoft Exc...
#                                            ^^^^^^
# ***********this other cases****************
# Offset 637, length 7, Rule ID: THERE_RE_MANY
# Message: Possible agreement error. Did you mean “programs”?
# Suggestion: programs
# ... system. For example,there are computer program like Microsoft Excel can solve complex ...
#                                            ^^^^^^^
# ***********this other cases****************
# Offset 957, length 9, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: although
# ...thematics as a learning basic in school althought it might not be used in future. The rea...
#                                            ^^^^^^^^^
# ***********this other cases****************
# Offset 1169, length 7, Rule ID: OXFORD_SPELLING_Z_NOT_S
# Message: Would you like to use the Oxford spelling “realize”? The spelling ‘realise’ is also correct.
# Suggestion: realize
# ... surrounding. For example, children can realise directly if the change gotten is in wro...
#                                            ^^^^^^^
# ***********this other cases****************
# Offset 1200, length 6, Rule ID: GOT_GOTTEN
# Message: In the UK, the word ‘gotten’ is not used. Did you mean “got”?
# Suggestion: got
# ...dren can realise directly if the change gotten is in wrong amount when they buy someth...
#                                            ^^^^^^
# ***********this other cases****************
# Offset 1471, length 5, Rule ID: BEEN_PART_AGREEMENT
# Message: Consider using either the past participle “agreed” or the present participle “agreeing” here.
# Suggestion: agreed; agreeing
# ...ry in school syllabus? Some parents are agree but some parents are not. This essay di...
#                                            ^^^^^
# ***********this other cases****************
# Offset 1476, length 4, Rule ID: COMMA_COMPOUND_SENTENCE_2
# Message: Use a comma before ‘but’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , but
# ... school syllabus? Some parents are agree but some parents are not. This essay discus...
#                                            ^^^^
# total count  9
# 113
# ***********this the US case/case to ignore****************
# Offset 1005, length 7, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘harbors’ is American English.
# Suggestion: harbours
# ...tive than other candidates if he or she harbors a wide range of highly specialized know...
#                                            ^^^^^^^
# ***********this the US case/case to ignore****************
# Offset 1537, length 4, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘vise’ is American English.
# Suggestion: vice
# ...ason to force them to learn science and vise versa.  In sum, the most important aim ...
#                                            ^^^^
# ***********this other cases****************
# Offset 1688, length 2, Rule ID: NON3PRS_VERB
# Message: The pronoun ‘is’ must be used with “are”.
# Suggestion: are
# ...ed abilities and personal traits, which is we should indeed focus on rather than t...
#                                            ^^
# total count  1
# 114
# ***********this other cases****************
# Offset 786, length 5, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: Poll; Polls; Apollo; Polo; Polio; Polly; Rollo
# ... their development. William James Marco Pollo, an educational consultant, believed th...
#                                            ^^^^^
# total count  1
# 115
# ***********this other cases****************
# Offset 379, length 10, Rule ID: THESE_ONES
# Message: In formal contexts, “these” is sufficient.
# Suggestion: these
# ...ments have to ban dangerous games since these ones have a potential risk which players can...
#                                            ^^^^^^^^^^
# ***********this other cases****************
# Offset 662, length 10, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: free diving
# ...ctions negatively affects on them. Take freediving as an example, to play this game, a gam...
#                                            ^^^^^^^^^^
# ***********this other cases****************
# Offset 756, length 4, Rule ID: COMMA_COMPOUND_SENTENCE
# Message: Use a comma before ‘and’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , and
# ...hould be a diving expert, not an amateur and he needs to know his health condition t...
#                                            ^^^^
# ***********this the US case/case to ignore****************
# Offset 1327, length 9, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘practiced’ is American English.
# Suggestion: practised
# ...n the outside environment, experts have practiced in harmless places, thus they can manag...
#                                            ^^^^^^^^^
# total count  3
# 116
# ***********this other cases****************
# Offset 336, length 4, Rule ID: COMMA_COMPOUND_SENTENCE_2
# Message: Use a comma before “and” if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , and
# ...ferent aspects. Both views are discussed and my perspective will be proposed later. ...
#                                            ^^^^
# ***********this other cases****************
# Offset 668, length 4, Rule ID: COMMA_COMPOUND_SENTENCE_2
# Message: Use a comma before “and” if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , and
# ...in a match, all of them have to collapse and each person needs to express their capa...
#                                            ^^^^
# ***********this the US case/case to ignore****************
# Offset 1366, length 10, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘practicing’ is American English.
# Suggestion: practising
# ...rtners which lead to delay the process, practicing alone helps athletes to save time and f...
#                                            ^^^^^^^^^^
# ***********this the US case/case to ignore****************
# Offset 1980, length 10, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘practicing’ is American English.
# Suggestion: practising
# ...e played alone due to the efficiency in practicing. I am in the middle of the scale and be...
#                                            ^^^^^^^^^^
# total count  2
# 117
# ***********this the US case/case to ignore****************
# Offset 43, length 23, Rule ID: WHETHER
# Message: Wordiness: Consider shortening this phrase.
# Suggestion: whether; the question whether
# ...ple have differing views with regard to the question of whether or not zoos need to be maintained. Whil...
#                                            ^^^^^^^^^^^^^^^^^^^^^^^
# ***********this the US case/case to ignore****************
# Offset 1473, length 9, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘behaviors’ is American English.
# Suggestion: behaviours
# ...ct them from poachers and these immoral behaviors.  In conclusion, although some people b...
#                                            ^^^^^^^^^
# total count  0
# 118
# ***********this other cases****************
# Offset 35, length 4, Rule ID: COMMA_COMPOUND_SENTENCE
# Message: Use a comma before ‘and’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , and
# A number of people choose a company and they stay with this organization for th...
#                                    ^^^^
# ***********this other cases****************
# Offset 1530, length 8, Rule ID: ADJECTIVE_ADVERB
# Message: The word “constant” is an adjective and doesn’t fit in this context. Did you mean the adverb “constantly”?
# Suggestion: constantly
# ...lexible ability to adapt effectively to constant changing of the economic system.  In co...
#                                            ^^^^^^^^
# total count  2
# 119
# ***********this the US case/case to ignore****************
# Offset 1127, length 8, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘skillful’ is American English.
# Suggestion: skilful
# ...e age of 35, he is regarded as the most skillful football player due to impressive recor...
#                                            ^^^^^^^^
# total count  0
# 120
# ***********this other cases****************
# Offset 879, length 4, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: sold; self; solo; golf; sole; wolf; Rolf; sols; OLF; SLF; Sol; Wolf; sol
# ...comprehensively develop a wide range of solf skills. To be more specific, when pupil...
#                                            ^^^^
# ***********this other cases****************
# Offset 1141, length 15, Rule ID: ADVERB_OR_HYPHENATED_ADJECTIVE
# Message: Make sure that the adjective ‘attending’ is correct. Possibly, it should be an adverb (typically ~ly) that modifies ‘mixed’. Possibly, it should be the first word in a compound adjective (hyphenated adjective). Possibly, it is correct.
# ... and potentials. Another reason is that attending mixed schools ensures co-existence and gender...
#                                            ^^^^^^^^^^^^^^^
# total count  2
# 121
# ***********this other cases****************
# Offset 156, length 5, Rule ID: OTHER_OTHERS
# Message: It seems that the plural noun “others” fits better in this context.
# Suggestion: others
# ... solutions to avoid them of it, whereas other think contrarily, it is not important t...
#                                            ^^^^^
# ***********this other cases****************
# Offset 1219, length 6, Rule ID: AFFECT_EFFECT
# Message: Did you mean “affect” (have an effect upon)?
# Suggestion: affect
# ... also been proven that education cannot effect people to eat junk food. Plenty of them...
#                                            ^^^^^^
# total count  2
# 122
# ***********this other cases****************
# Offset 486, length 3, Rule ID: COMMA_COMPOUND_SENTENCE
# Message: Use a comma before ‘so’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , so
# ...icycle does not consume any fossil fuels so it cannot emit any carbon dioxide into ...
#                                            ^^^
# ***********this the US case/case to ignore****************
# Offset 1259, length 9, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘traveling’ is American English.
# Suggestion: travelling
# ...e and transport goods faster. Secondly, traveling by public transportation will save citi...
#                                            ^^^^^^^^^
# total count  1
# 123
# ***********this other cases****************
# Offset 947, length 9, Rule ID: CA_BRAND_NEW
# Message: ‘brand new’ seems to be a compound adjective before a noun. Use a hyphen: “brand-new”.
# Suggestion: brand-new
# ...ink that spending money on constructing brand new train lines for high-speed vehicles is ...
#                                            ^^^^^^^^^
# ***********this other cases****************
# Offset 1164, length 9, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# ...spend 5 to 6 hours going from Taipei to Kaohsiung, they spend only 2 or 3 hours if they t...
#                                            ^^^^^^^^^
# total count  2
# 124
# ***********this other cases****************
# Offset 220, length 6, Rule ID: TIK_TOK
# Message: Did you mean “TikTok” (= social networking app)?
# Suggestion: TikTok
# ...d countries in the same year.  Overall, Tiktok was the topmost over the period in term...
#                                            ^^^^^^
# ***********this other cases****************
# Offset 343, length 6, Rule ID: TIK_TOK
# Message: Did you mean “TikTok” (= social networking app)?
# Suggestion: TikTok
# ...Indian residents got the most access to Tiktok yearly. Concerning the international mo...
#                                            ^^^^^^
# ***********this other cases****************
# Offset 414, length 6, Rule ID: TIK_TOK
# Message: Did you mean “TikTok” (= social networking app)?
# Suggestion: TikTok
# ...nternational monthly downloads in 2020, Tiktok was by far the most downloaded in Janua...
#                                            ^^^^^^
# ***********this other cases****************
# Offset 666, length 6, Rule ID: TIK_TOK
# Message: Did you mean “TikTok” (= social networking app)?
# Suggestion: TikTok
# ... point of over 40 million in September, Tiktok remained in the first rank in this resp...
#                                            ^^^^^^
# ***********this other cases****************
# Offset 966, length 12, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# ...Having a closer look at the table data, Tiktok-users continued to account for the majority i...
#                                            ^^^^^^^^^^^^
# ***********this other cases****************
# Offset 1075, length 7, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. Did you mean “equalled”, the past tense form of the verb ‘equal’?
# Suggestion: equalled; equated
# ...while the American "netizens" virtually equaled the downloads of 3 apps. India witnesse...
#                                            ^^^^^^^
# ***********this other cases****************
# Offset 1180, length 6, Rule ID: TIK_TOK
# Message: Did you mean “TikTok” (= social networking app)?
# Suggestion: TikTok
# ...ortion of the social media's downloads (Tiktok, Facebook, and Instagram) in 2020, 99.8...
#                                            ^^^^^^
# total count  7
# 125
# ***********this other cases****************
# Offset 384, length 4, Rule ID: COMMA_COMPOUND_SENTENCE
# Message: Use a comma before ‘but’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , but
# ...Both approaches have their pros and cons but I lean towards the second one. This ess...
#                                            ^^^^
# ***********this other cases****************
# Offset 1695, length 4, Rule ID: HE_NEED
# Message: The pronoun ‘it’ requires a third-person verb or a past tense.
# Suggestion: needs; needed
# ... its existence and development since it need to turn over a new leaf constantly to a...
#                                            ^^^^
# total count  2
# 126
# ***********this other cases****************
# Offset 1881, length 16, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: short-sightedness; short sightedness
# ... a result, diseases such as obesity and shortsightedness can be prevented.  In conclusion, altho...
#                                            ^^^^^^^^^^^^^^^^
# total count  1
# 127
# ***********this the US case/case to ignore****************
# Offset 133, length 8, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘endeavor’ is American English.
# Suggestion: endeavour
# ...nsable way to uphold the motivation and endeavor for working. One of the most common met...
#                                            ^^^^^^^^
# ***********this other cases****************
# Offset 363, length 16, Rule ID: EN_COMPOUNDS
# Message: This word is normally spelled as one.
# Suggestion: extraordinary
# ...ere are several measures to tribute the extra - ordinary staff which are required to be taken ra...
#                                            ^^^^^^^^^^^^^^^^
# ***********this the US case/case to ignore****************
# Offset 472, length 7, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘analyze’ is American English.
# Suggestion: analyse
# ...nding on their demands. This essay will analyze the practice above comprehensively and ...
#                                            ^^^^^^^
# ***********this other cases****************
# Offset 896, length 4, Rule ID: SENTENCE_WHITESPACE
# Message: Add a space between sentences.
# Suggestion:  They
# ...afety, employment to make ends meet, ...They are mainly manual laborers or employees...
#                                            ^^^^
# ***********this other cases****************
# Offset 919, length 8, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: labourers
# ...ke ends meet, ...They are mainly manual laborers or employees with low salary, easily be...
#                                            ^^^^^^^^
# ***********this the US case/case to ignore****************
# Offset 1516, length 7, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘fulfill’ is American English.
# Suggestion: fulfil
# ...al benefits, including a high salary to fulfill their lowest human needs, they are on t...
#                                            ^^^^^^^
# ***********this other cases****************
# Offset 1602, length 13, Rule ID: EN_COMPOUNDS
# Message: This word is normally spelled with a hyphen.
# Suggestion: self-esteem
# ...their ways to reach higher ones such as self - esteem and -actualization. As the matter of fa...
#                                            ^^^^^^^^^^^^^
# ***********this other cases****************
# Offset 1720, length 12, Rule ID: HARD_WORKING_COMPOUND
# Message: This adjective is spelled with a hyphen or as one word.
# Suggestion: hardworking; hard-working
# ...ct from others act as a trigger for the hard working and substantial contribution. Based on ...
#                                            ^^^^^^^^^^^^
# ***********this the US case/case to ignore****************
# Offset 1939, length 5, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘honor’ is American English.
# Suggestion: honour
# ... year..., presenting their names on the honor board or as representatives of the comp...
#                                            ^^^^^
# ***********this other cases****************
# Offset 1990, length 7, Rule ID: SENTENCE_WHITESPACE
# Message: Add a space between sentences.
# Suggestion:  Another
# ... or as representatives of the company...Another means is to reward them with a further ...
#                                            ^^^^^^^
# ***********this other cases****************
# Offset 2301, length 17, Rule ID: LARGE_NUMBER_OF
# Message: Specify a number, remove phrase, or simply use “many” or “numerous”
# Suggestion: many; numerous
# ...able style of management that satisfies a large number of the company's members.
#                                            ^^^^^^^^^^^^^^^^^
# total count  7
# 128
# ***********this other cases****************
# Offset 139, length 5, Rule ID: ONE_OF
# Message: Please check whether a plural form of ‘issue’ should be used.
# Suggestion: issues
# ...ol hours is one of the most challenging issue in education. While some people deem th...
#                                            ^^^^^
# ***********this other cases****************
# Offset 492, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Don’t put a space before the full stop.
# Suggestion: .
# ...has a number of dire drawbacks to pupils . Children spend the bulk of their time a...
#                                            ^^
# total count  2
# 129
# ***********this other cases****************
# Offset 557, length 12, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: short-sighted; short sighted
# ...s. However, I believe this to be a very shortsighted view, as it usually does not cover othe...
#                                            ^^^^^^^^^^^^
# total count  1
# 130
# ***********this the US case/case to ignore****************
# Offset 1116, length 7, Rule ID: EN_GB_SIMPLE_REPLACE
# Message: ‘garbage’ is a common American expression. Consider using expressions more common to British English.
# Suggestion: rubbish
# ...re littering in the park or discharging garbage into the river.  Nonetheless, a negativ...
#                                            ^^^^^^^
# total count  0
# 131
# ***********this other cases****************
# Offset 703, length 2, Rule ID: ENGLISH_WORD_REPEAT_BEGINNING_RULE
# Message: Three successive sentences begin with the same word. Consider rewording the sentence or use a thesaurus to find a synonym.
# ...part of lessons they do not understand. In addition, as extra coaching classes gen...
#                                            ^^
# ***********this other cases****************
# Offset 816, length 11, Rule ID: MOST_COMPARATIVE
# Message: Use only “better” (without ‘more’) when you use the comparative.
# Suggestion: better
# ...ar subject, the teaching method is much more better than at school and students are able to...
#                                            ^^^^^^^^^^^
# ***********this other cases****************
# Offset 1742, length 4, Rule ID: COMMA_COMPOUND_SENTENCE
# Message: Use a comma before ‘and’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , and
# ...elp students in their study a great deal and they will get result after studying ext...
#                                            ^^^^
# ***********this other cases****************
# Offset 1917, length 8, Rule ID: SO_AS_TO
# Message: ‘So as to’ expresses purpose and is used in formal texts. Consider using “to”
# Suggestion: to
# ...ome leisure activities apart from study so as to refreshing their mind and relax.
#                                            ^^^^^^^^
# total count  4
# 132
# ***********this other cases****************
# Offset 1289, length 17, Rule ID: LARGE_NUMBER_OF
# Message: Specify a number, remove phrase, or simply use “many” or “numerous”
# Suggestion: many; numerous
# ...y can avoid social isolation. There are a large number of events belonging to the new country suc...
#                                            ^^^^^^^^^^^^^^^^^
# ***********this other cases****************
# Offset 1557, length 7, Rule ID: SENT_START_CONJUNCTIVE_LINKING_ADVERB_COMMA
# Message: A comma may be missing after the conjunctive/linking adverb ‘However’.
# Suggestion: However,
# ...s when beginning to live in a new land. However it would not be easy but I completely a...
#                                            ^^^^^^^
# ***********this other cases****************
# Offset 1585, length 4, Rule ID: COMMA_COMPOUND_SENTENCE
# Message: Use a comma before ‘but’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , but
# ...a new land. However it would not be easy but I completely agree with this opinion.
#                                            ^^^^
# total count  3
# 133
# ***********this other cases****************
# Offset 985, length 5, Rule ID: SPURIOUS_APOSTROPHE
# Message: The possessive apostrophe seems to be incorrect. Please remove the apostrophe if you want to use the plural form of ‘man’.
# Suggestion: men
# ...inate the planet and conquer beyond any man's wildest dream.  On the other hand, chas...
#                                            ^^^^^
# total count  1
# 134
# total count  0
# 135
# ***********this other cases****************
# Offset 595, length 12, Rule ID: FIRST_OF_ALL
# Message: Often, this adverbial phrase is redundant. Consider using an alternative.
# Suggestion: First; Foremost
# ...cting maximum number of working hours.  First of all, many of us would agree to the fact tha...
#                                            ^^^^^^^^^^^^
# ***********this other cases****************
# Offset 1361, length 3, Rule ID: COMMA_COMPOUND_SENTENCE
# Message: Use a comma before ‘so’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , so
# ...they usually remain busy in their office so they do not find leisure time for such ...
#                                            ^^^
# ***********this other cases****************
# Offset 1750, length 4, Rule ID: COMMA_COMPOUND_SENTENCE
# Message: Use a comma before ‘but’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , but
# ...rwards and now trying to manage his work but it seems to be too late for him.  To co...
#                                            ^^^^
# ***********this the US case/case to ignore****************
# Offset 1824, length 8, Rule ID: EMPHASIS_EMPHASIZE
# Message: Did you mean “emphasize” (American English) or “emphasise” (British English)?
# Suggestion: emphasize; emphasise
# ...im.  To conclude this, I would strongly emphasis and recommend, Government must include ...
#                                            ^^^^^^^^
# ***********this the US case/case to ignore****************
# Offset 1925, length 5, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘Labor’ is American English.
# Suggestion: Labour
# ... maximum number of working hours in its Labor Law and enforce to all companies for en...
#                                            ^^^^^
# total count  3
# 136
# ***********this other cases****************
# Offset 563, length 6, Rule ID: HAVE_PART_AGREEMENT
# Message: Possible agreement error -- use the past participle here.
# Suggestion: invented
# ...w ideas that people need it but haven't invent it. By doing so, it requires the creati...
#                                            ^^^^^^
# ***********this other cases****************
# Offset 656, length 5, Rule ID: HAVE_PART_AGREEMENT
# Message: Possible agreement error -- use the past participle here.
# Suggestion: existed
# ...to invent the new products that haven't exist and the ability to find out the people'...
#                                            ^^^^^
# ***********this other cases****************
# Offset 990, length 8, Rule ID: ADVISE_VBG
# Message: The verb ‘helps’ is used with an infinitive.
# Suggestion: to think; think
# ...essive one step by step, which helps us thinking more logically and find out people's ne...
#                                            ^^^^^^^^
# ***********this other cases****************
# Offset 1230, length 9, Rule ID: ARTICLE_ADJECTIVE_OF
# Message: Did you mean the noun “importance”?
# Suggestion: importance
# ...hat he mentioned not only one times the important of art and philosophy effected his way ...
#                                            ^^^^^^^^^
# ***********this other cases****************
# Offset 1793, length 9, Rule ID: TO_NON_BASE
# Message: The verb after “to” should be in the base form.
# Suggestion: improve
# ... need to learn art subjects in order to improving the creativities and logical thinking. ...
#                                            ^^^^^^^^^
# total count  5
# 137
# ***********this other cases****************
# Offset 279, length 4, Rule ID: COMMA_COMPOUND_SENTENCE
# Message: Use a comma before ‘and’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , and
# ...y, I feel that such a conclusion is nave and I will support my opinion in this essay...
#                                            ^^^^
# ***********this other cases****************
# Offset 326, length 12, Rule ID: FIRST_OF_ALL
# Message: Often, this adverbial phrase is redundant. Consider using an alternative.
# Suggestion: First; Foremost
# ...will support my opinion in this essay.  First of all, children may have no chance of educati...
#                                            ^^^^^^^^^^^^
# ***********this other cases****************
# Offset 1145, length 5, Rule ID: MD_BASEFORM
# Message: The modal verb ‘should’ requires the verb’s base form.
# Suggestion: spend
# ... think we can agree that mothers should spent more time to paying attention for their...
#                                            ^^^^^
# total count  3
# 138
# ***********this other cases****************
# Offset 387, length 10, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: high school
# ...n and effort. Some people commonly take highschool study for granted then don't usually le...
#                                            ^^^^^^^^^^
# ***********this other cases****************
# Offset 877, length 3, Rule ID: COMMA_COMPOUND_SENTENCE_2
# Message: Use a comma before ‘so’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , so
# ... are being on the way of becoming adults so there are still a wide range of things ...
#                                            ^^^
# ***********this other cases****************
# Offset 1060, length 10, Rule ID: THIS_NNS
# Message: The plural demonstrative ‘these’ does not agree with the singular noun ‘mess’.
# Suggestion: this mess; these messes
# ...s and then don't know how to get out of these mess. For example, young people can easily b...
#                                            ^^^^^^^^^^
# ***********this other cases****************
# Offset 1840, length 4, Rule ID: COMMA_COMPOUND_SENTENCE
# Message: Use a comma before ‘and’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , and
# ... when concerning people who are under 18 and it should widely be favoured by governm...
#                                            ^^^^
# total count  4
# 139
# ***********this other cases****************
# Offset 971, length 15, Rule ID: A_INFINITIVE
# Message: After ‘the’, the verb ‘deteriorate’ doesn’t fit. Is ‘deteriorate’ spelled correctly? If ‘deteriorate’ is the first word in a compound adjective, use a hyphen between the two words. Using the verb ‘deteriorate’ as a noun may be non-standard.
# Suggestion: to deteriorate; the deteriorated
# ...s emission and pollution. Consequently, the deteriorate pollution could be combatted by control...
#                                            ^^^^^^^^^^^^^^^
# total count  1
# 140
# ***********this other cases****************
# Offset 121, length 5, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: should; shout; shroud; SOUD; shod
# ...imes the defendant had done in the past shoud be reached by the jury of a court in or...
#                                            ^^^^^
# ***********this other cases****************
# Offset 399, length 8, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: disagree
# ... a right conclusion. However, I totally diasgree with this suggestion, considering that ...
#                                            ^^^^^^^^
# ***********this other cases****************
# Offset 507, length 3, Rule ID: ONE_THE_ONE_HAND
# Message: Did you mean “on”?
# Suggestion: On
# ...e able to fully eclipse the downsides.  One the one hand, this idea brings out the ...
#                                            ^^^
# ***********this other cases****************
# Offset 776, length 10, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: relevant; irrelevant
# ...of the defendant. This might seem to be unrelevant to some people; however, in many cases ...
#                                            ^^^^^^^^^^
# ***********this other cases****************
# Offset 1220, length 10, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: properly; improperly
# ...on, hence make them easily judge things unproperly. That what people did in the past do no...
#                                            ^^^^^^^^^^
# ***********this the US case/case to ignore****************
# Offset 1664, length 7, Rule ID: ANYMORE
# Message: In British English, the spelling ‘anymore’ is sometimes considered incorrect. Did you mean “any more”?
# Suggestion: any more
# ...he equality in court might not maintain anymore.
#                                            ^^^^^^^
# total count  5
# 141
# ***********this other cases****************
# Offset 314, length 4, Rule ID: COMMA_COMPOUND_SENTENCE
# Message: Use a comma before ‘and’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , and
# ...he bad impact of treatments and medicine and it will elaborate how government can pl...
#                                            ^^^^
# ***********this other cases****************
# Offset 440, length 10, Rule ID: NOW_A_DAYS
# Message: Did you mean “nowadays”?
# Suggestion: nowadays
# ...each disease is really much more costly now a days, and lower family can not afford such b...
#                                            ^^^^^^^^^^
# total count  2
# 142
# ***********this other cases****************
# Offset 138, length 4, Rule ID: COMMA_COMPOUND_SENTENCE
# Message: Use a comma before ‘and’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , and
# ...quence, people have become more indolent and they are no longer socialising with oth...
#                                            ^^^^
# ***********this other cases****************
# Offset 162, length 11, Rule ID: OXFORD_SPELLING_Z_NOT_S
# Message: Would you like to use the Oxford spelling “socializing”? The spelling ‘socialising’ is also correct.
# Suggestion: socializing
# ...me more indolent and they are no longer socialising with others. I strongly agree with this...
#                                            ^^^^^^^^^^^
# ***********this other cases****************
# Offset 1076, length 11, Rule ID: OXFORD_SPELLING_Z_NOT_S
# Message: Would you like to use the Oxford spelling “socializing”? The spelling ‘socialising’ is also correct.
# Suggestion: socializing
# ...d to spend my free time doing sports or socialising with my friends. However, nowadays chil...
#                                            ^^^^^^^^^^^
# ***********this other cases****************
# Offset 1114, length 8, Rule ID: NOWADAYS_COMMA
# Message: Consider adding a comma after this introductory expression.
# Suggestion: nowadays,
# ...r socialising with my friends. However, nowadays children are more and more addicted to ...
#                                            ^^^^^^^^
# total count  4
# 143
# ***********this other cases****************
# Offset 269, length 12, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: misdemeanours
# ...plementing harsh punishments on driving misdemeanors.  On the one hand, there are justified ...
#                                            ^^^^^^^^^^^^
# ***********this other cases****************
# Offset 406, length 12, Rule ID: FIRST_OF_ALL
# Message: Often, this adverbial phrase is redundant. Consider using an alternative.
# Suggestion: First; Foremost
# ...s in order to reform traffic wellbeing. First of all, the government dispel any ideas of the...
#                                            ^^^^^^^^^^^^
# ***********this the US case/case to ignore****************
# Offset 648, length 7, Rule ID: LICENCE_LICENSE_NOUN_SINGULAR
# Message: license must be spelled with a “c” when used as a noun in British English. Use “licence”.
# Suggestion: licence
# ... increasing the amount of fine, driving license suspension, imprisonment,... Additional...
#                                            ^^^^^^^
# ***********this other cases****************
# Offset 680, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Put a space after the comma.
# Suggestion: , .
# ...driving license suspension, imprisonment,... Additionally, people are stimulated t...
#                                            ^^
# ***********this other cases****************
# Offset 841, length 10, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake found.
# Suggestion: instantly
# ...e gets punished heavily, he or she will instantlly be more careful by paying more attentio...
#                                            ^^^^^^^^^^
# ***********this the US case/case to ignore****************
# Offset 1420, length 9, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘traveling’ is American English.
# Suggestion: travelling
# ...tudents and senior citizens. Hopefully, traveling by public transports like buses or trai...
#                                            ^^^^^^^^^
# ***********this other cases****************
# Offset 1757, length 10, Rule ID: EN_COMPOUNDS
# Message: This word is normally spelled as one.
# Suggestion: joyriding
# ...eet the flow of vehicles. For example, "joy riding" is arised when someone steal cars and ...
#                                            ^^^^^^^^^^
# ***********this other cases****************
# Offset 1772, length 6, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. Did you mean “arose”, the past tense form of the verb ‘arise’?
# Suggestion: arose; raised; arise; arises; arisen; prised; ariser; arsed
# ... vehicles. For example, "joy riding" is arised when someone steal cars and drive them ...
#                                            ^^^^^^
# ***********this other cases****************
# Offset 2054, length 8, Rule ID: SO_AS_TO
# Message: ‘So as to’ expresses purpose and is used in formal texts. Consider using “to”
# Suggestion: to
# ...uld be well-informed about traffic laws so as to minimize offences on the road.  In conc...
#                                            ^^^^^^^^
# ***********this the US case/case to ignore****************
# Offset 2110, length 8, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘leveling’ is American English.
# Suggestion: levelling
# ...e offences on the road.  In conclusion, leveling fine status is not the only solution to...
#                                            ^^^^^^^^
# ***********this other cases****************
# Offset 2192, length 18, Rule ID: NUMEROUS_DIFFERENT
# Message: Consider using “numerous”.
# Suggestion: numerous
# ...ion to improve road safety as there are numerous different approaches to tackle aforementioned iss...
#                                            ^^^^^^^^^^^^^^^^^^
# total count  8
# 144
# ***********this other cases****************
# Offset 158, length 17, Rule ID: BASIC_FUNDAMENTALS
# Message: Consider using “necessities”.
# Suggestion: necessities
# ...g, while the poor is struggle to afford basic necessities. Some people suggest that government sh...
#                                            ^^^^^^^^^^^^^^^^^
# ***********this other cases****************
# Offset 1336, length 1, Rule ID: EN_A_VS_AN
# Message: Use “an” instead of ‘a’ if the following word starts with a vowel sound, e.g. ‘an article’, ‘an hour’.
# Suggestion: an
# ... to live by is the best way to maintain a ideal society. Relief bills, which usua...
#                                            ^
# ***********this other cases****************
# Offset 1399, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Put a space after the comma, but not before the comma.
# Suggestion: ,
# ... bills, which usually signed amid crises , are a good example to demonstrate. They...
#                                            ^^
# ***********this other cases****************
# Offset 1746, length 4, Rule ID: COMMA_COMPOUND_SENTENCE
# Message: Use a comma before ‘but’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , but
# ... that not only does it boost the economy but it also stabilizes the society.
#                                            ^^^^
# total count  4
# 145
# ***********this the US case/case to ignore****************
# Offset 217, length 8, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘skillful’ is American English.
# Suggestion: skilful
# ...training because of the current lack of skillful workers. From my perspective, ability a...
#                                            ^^^^^^^^
# ***********this the US case/case to ignore****************
# Offset 543, length 4, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘math’ is American English.
# Suggestion: maths
# ... example, if their children could solve math problems efficiently, they should be ki...
#                                            ^^^^
# ***********this the US case/case to ignore****************
# Offset 732, length 8, Rule ID: MORFOLOGIK_RULE_EN_GB
# Message: Possible spelling mistake. ‘skillful’ is American English.
# Suggestion: skilful
# ...appropriate choice for them. Otherwise, skillful children could become workers so that t...
#                                            ^^^^^^^^
# ***********this other cases****************
# Offset 922, length 12, Rule ID: FIRST_OF_ALL
# Message: Often, this adverbial phrase is redundant. Consider using an alternative.
# Suggestion: First; Foremost
# ...en into account because of two reasons. First of all, if graduates can work with their inter...
#                                            ^^^^^^^^^^^^
# ***********this other cases****************
# Offset 1312, length 3, Rule ID: COMMA_COMPOUND_SENTENCE
# Message: Use a comma before ‘so’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , so
# ...do and tend to continue their employment so they could have more opportunities for ...
#                                            ^^^
# ***********this other cases****************
# Offset 1754, length 3, Rule ID: COMMA_COMPOUND_SENTENCE
# Message: Use a comma before ‘or’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , or
# ...y aptitude in finding electricity errors or they do not have strength enough to bec...
#                                            ^^^
# total count  3
# 146
# total count  0
# 147
# ***********this other cases****************
# Offset 1793, length 1, Rule ID: I_LOWERCASE
# Message: The personal pronoun “I” should be uppercase.
# Suggestion: I
# ...rved as one of the essential abilities, i also acknowledge that other social and ...
#                                            ^
# total count  1
# 148
# ***********this other cases****************
# Offset 47, length 8, Rule ID: WILL_BASED_ON
# Message: Typo. Did you mean “be replaced”?
# Suggestion: be replaced
# ...ng whether traditional buildings should replaced by the contemporary buildings brings th...
#                                            ^^^^^^^^
# ***********this other cases****************
# Offset 351, length 12, Rule ID: FIRST_OF_ALL
# Message: Often, this adverbial phrase is redundant. Consider using an alternative.
# Suggestion: First; Foremost
# ...am on the opposite side of this claim.  First of all, not all the old houses are necessarily...
#                                            ^^^^^^^^^^^^
# ***********this other cases****************
# Offset 557, length 4, Rule ID: COMMA_COMPOUND_SENTENCE
# Message: Use a comma before ‘and’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , and
# ...ave been going through the China History and it is such an awesome style that impres...
#                                            ^^^^
# ***********this other cases****************
# Offset 807, length 4, Rule ID: COMMA_COMPOUND_SENTENCE
# Message: Use a comma before ‘and’ if it connects two independent clauses (unless they are closely connected and short).
# Suggestion: , and
# ...e adapted to the old living surroundings and it seems not too easy to change that. I...
#                                            ^^^^
# ***********this other cases****************
# Offset 883, length 9, Rule ID: DROP_DOWN
# Message: This phrase is redundant. Consider using “drop”.
# Suggestion: drop
# ... that. If all the traditional buildings drop down, some people will lose their home. For ...
#                                            ^^^^^^^^^
# ***********this other cases****************
# Offset 974, length 9, Rule ID: APARTMENT-FLAT
# Message: The word ‘apartment’ is common for American English. Did you mean “flat”?
# Suggestion: flat
# ...stance, many elder people live in their apartment during their whole life, and they never...
#                                            ^^^^^^^^^
# total count  6
# 149
# total count  0
# The number of columns in the CSV file is: 37

# %%
data_prev1 = pd.read_csv('../../csv/human/csv_human-2.csv')
#data1=data_prev1.iloc[:76, :].copy()

# %%
data.to_csv('../../csv/human/csv_human-2.csv',mode='a',header=None,index=False)

# %%
merged_df = pd.concat([data_prev1, data], axis=0)

# %%
merged_df

# %%
merged_df.to_csv('../csv/human/csv_human-2.csv',index=False)
