# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('../../csv/gpt/csv_gpt3-1.csv')
df2 = pd.read_csv('../../csv/human/csv_human-1.csv')

# %%
df1

# %%
df_test=df1.groupby(['para_count'])

# %%
print(df_test)

# %%
print(df1.dtypes)

# %%
df2_corr=df1.corr()
df2_corr.to_csv('human_correlation.csv', header=True)
# Out:
# /tmp/ipykernel_278540/946592843.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2_corr=df1.corr()

# %%
import seaborn as sns
sns.regplot(x="para_count", y="word_count", data=df1)
plt.ylim(0,)
# Out:
# (0.0, 564.55)

# %%
df1.describe()
# Out:
#        para_count  word_count  sentence_count  sentence_len(mean)  \
# count  143.000000  143.000000      143.000000          143.000000
# mean     5.867133  405.580420       20.531469           19.907985
# std      0.780373   51.404282        3.096577            1.950648
# min      4.000000  196.000000       12.000000           16.066667
# 25%      5.000000  370.000000       18.000000           18.489130
# 50%      6.000000  402.000000       20.000000           19.888889
# 75%      6.000000  441.500000       23.000000           21.306150
# max      8.000000  547.000000       30.000000           25.166667
#
#        sentence_len(mode)  sentence_len(max)  sentence_len(min)  stop_words  \
# count          143.000000          143.00000         143.000000  143.000000
# mean            19.027972           32.00000          10.055944  184.944056
# std              4.632926            4.51913           2.422826   25.192436
# ...

# %%
df2.describe()
# Out:
#        para_count   word_count  sentence_count  sentence_len(mean)  \
# count  143.000000   143.000000      143.000000          143.000000
# mean     4.461538   326.293706       16.286713           20.875271
# std      0.802893    92.045903        6.223108            4.024385
# min      3.000000   225.000000        8.000000           11.041667
# 25%      4.000000   275.500000       13.000000           17.989464
# 50%      4.000000   310.000000       15.000000           21.000000
# 75%      5.000000   347.000000       18.000000           22.968750
# max     11.000000  1029.000000       63.000000           32.636364
#
#        sentence_len(mode)  sentence_len(max)  sentence_len(min)  stop_words  \
# count          143.000000         143.000000         143.000000  143.000000
# mean            18.972028          37.874126           9.699301  172.069930
# std              6.631067          10.596882           3.171251   54.331099
# ...

# %%
# Calculate the describe() statistics for each DataFrame
describe_df1 = df1.describe()
describe_df2 = df2.describe()

# Calculate the absolute differences between the statistics
describe_diff = describe_df1.sub(describe_df2).abs()

# Display the comparison results
print("Comparison of DataFrame 1 with DataFrame 2:")
print(describe_diff)
# Out:
# Comparison of DataFrame 1 with DataFrame 2:
#        para_count  word_count  sentence_count  sentence_len(mean)  \
# count    0.000000    0.000000        0.000000            0.000000
# mean     1.405594   79.286713        4.244755            0.967286
# std      0.022520   40.641622        3.126531            2.073737
# min      1.000000   29.000000        4.000000            5.025000
# 25%      1.000000   94.500000        5.000000            0.499667
# 50%      2.000000   92.000000        5.000000            1.111111
# 75%      1.000000   94.500000        5.000000            1.662600
# max      3.000000  482.000000       33.000000            7.469697
#
#        sentence_len(mode)  sentence_len(max)  sentence_len(min)  stop_words  \
# count            0.000000           0.000000           0.000000    0.000000
# mean             0.055944           5.874126           0.356643   12.874126
# std              1.998141           6.077752           0.748424   29.138663
# ...

# %%
describe_diff.to_csv('describe_output_difference.csv', header=True)

# %%
# Assuming you already have a DataFrame named 'data'
describe_result = df2.describe()

# Save the describe output directly to a CSV file
describe_result.to_csv('describe_output_gpt.csv', header=True)

# %%
pwd
# Out:
# 'f:\\codes\\mlenv1\\MastersThesis\\data analysis'

# %%
import seaborn as sns
fig = plt.figure(figsize=(20, 6))
sns.heatmap(df2.corr(), annot=True, cmap="coolwarm")

plt.show()
# Out:
# /tmp/ipykernel_278540/2439852185.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df2.corr(), annot=True, cmap="coolwarm")

# %%
corrmat = df1.corr()
fig = plt.figure(figsize = (12, 9))
sns.heatmap(corrmat, vmax = .8, square = True)
plt.show()

# %%
df1.head()

# %%
df1.shape
# Out:
# (90, 39)

# %%
df1.isna().sum()
# Out:
# essay                                    0
# topic                                    0
# para_count                               0
# word_count                               0
# sentence_count                           0
# sentence_len(mean)                       0
# sentence_len(mode)                       0
# sentence_len(max)                        0
# sentence_len(min)                        0
# stop_words                               0
# sw_rates                                 0
# unique_words                             0
# noun                                     0
# verb                                     0
# adj                                      0
# pron                                     0
# modal verb                               0
# most_freq                                0
# number_of_repeatation                    0
# max_occurance_of_most_frequent_phrase    0
# avg sentence complexity                  0
# lexical diversity                        0
# ...

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
pd.set_option('display.max_columns', None)
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 40 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   essay                                  143 non-null    object
#  1   topic                                  143 non-null    object
#  2   para_count                             143 non-null    float64
#  3   word_count                             143 non-null    float64
#  4   sentence_count                         143 non-null    float64
#  5   sentence_len(mean)                     143 non-null    float64
#  6   sentence_len(mode)                     143 non-null    float64
#  7   sentence_len(max)                      143 non-null    float64
#  8   sentence_len(min)                      143 non-null    float64
#  9   stop_words                             143 non-null    float64
# ...

# %%
pd.set_option('display.max_columns', None)
print(df2.nunique())
# Out:
# essay                                    143
# topic                                    143
# para_count                                 5
# word_count                                98
# sentence_count                            23
# sentence_len(mean)                       132
# sentence_len(mode)                        30
# sentence_len(max)                         37
# sentence_len(min)                         17
# stop_words                                88
# sw_rates                                 130
# unique_words                              81
# noun                                     143
# verb                                     140
# adj                                      138
# pron                                     135
# modal verb                                19
# most_freq                                 18
# number_of_repeatation                      9
# max_occurance_of_most_frequent_phrase      4
# avg sentence complexity                  108
# ...

# %%
print(df1.columns)
# Out:
# Index(['essay', 'topic', 'para_count', 'word_count', 'sentence_count',
#        'sentence_len(mean)', 'sentence_len(mode)', 'sentence_len(max)',
#        'sentence_len(min)', 'stop_words', 'sw_rates', 'unique_words', 'noun',
#        'verb', 'adj', 'pron', 'modal verb', 'most_freq',
#        'number_of_repeatation', 'max_occurance_of_most_frequent_phrase',
#        'avg sentence complexity', 'lexical diversity',
#        'sentence similarity mean', 'sentence similarity median',
#        'sentence similarity mode', 'word_sim_p_count', 'word_sim_p_score',
#        'word_sim_n_count', 'word_sim_n_score', 'word_sim_score',
#        'flesch grade', 'Automated Readability', 'coleman_liau',
#        'cohesion score', 'uniqueness of words', 'positive_sentiment',
#        'negative_sentiment', 'neutral_sentiment', 'discourse_marker', 'label'],
#       dtype='object')

# %%
import seaborn as sns
fig, axs = plt.subplots(1, 2, figsize=(15, 7))
plt.subplot(121)
sns.histplot(data=df1,x='sw_rates',bins=30,kde=True,color='g')
plt.subplot(122)
#sns.histplot(data=df1,x='uniqueness of words',kde=True,hue='para_count')
sns.histplot(data=df2,x='sw_rates',bins=30,kde=True)
plt.show()

# %%
column_name = 'essay'

duplicates = df2[df2.duplicated(subset=column_name, keep=False)]
print(duplicates)
# Out:
#                                                 essay  \
# 8   Over the last half century the change in the l...
# 42  Over the last half century the change in the l...
# 68  The last decade has seen an increasing number ...
# 71  The last decade has seen an increasing number ...
#
#                                                 topic  para_count  word_count  \
# 8   Email and text messaging threats written language         4.0       291.0
# 42        Lessons with teachers versus others sources         4.0       291.0
# 68  International tourism is now more common than ...         4.0       251.0
# 71  International tourism is now more common than ...         4.0       251.0
#
#     sentence_count  sentence_len(mean)  sentence_len(mode)  sentence_len(max)  \
# 8             14.0           20.785714                17.0               44.0
# 42            14.0           20.785714                17.0               44.0
# ...

# %%
plt.subplots(1,4,figsize=(16,5))
plt.subplot(141)
sns.boxplot(df1['word_count'],color='skyblue')
plt.subplot(142)
sns.boxplot(df1['sentence_count'],color='hotpink')
plt.subplot(143)
sns.boxplot(df1['discourse_marker'],color='yellow')
plt.subplot(144)
sns.boxplot(df1['uniqueness of words'],color='lightgreen')
plt.show()

# %%
plt.subplots(1,4,figsize=(16,5))
plt.subplot(141)
sns.boxplot(df2['word_count'],color='skyblue')
plt.subplot(142)
sns.boxplot(df2['sentence_count'],color='hotpink')
plt.subplot(143)
sns.boxplot(df2['discourse_marker'],color='yellow')
plt.subplot(144)
sns.boxplot(df2['uniqueness of words'],color='lightgreen')
plt.show()
