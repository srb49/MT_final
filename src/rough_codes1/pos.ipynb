# %%
import pandas as pd
import glob
import spacy
import statistics
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from spacy import displacy
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# !python -m spacy download en_core_web_lg

# %%
nlp = spacy.load("en_core_web_lg")

# %%
filename = input('Enter a filename: ')
with open('input/'+filename, 'r') as file:
 data = file.read()

# %%
def word_cnt(str1):
    words=str1.split()
    return len(words)

# %%
    data=" ".join(data.split())
    text = nlp(data)
    tags=[]
    for w in text:
    #print (w,"==", w.pos_)
        tags.append(w.pos_)

    from collections import Counter
    tag_freq = Counter(tags)
    print ("=====tag FREQUENCY=====")
    #print(tag_freq.values())
    w_l=word_cnt(data)
    for key in tag_freq:
        #print("hi")
        print("key is ",key," value ",tag_freq[key], " frequency ", tag_freq[key]/w_l)
    #print (tag_freq)
# Out:
# =====tag FREQUENCY=====
# key is  DET  value  47  frequency  0.11463414634146342
# key is  NOUN  value  89  frequency  0.21707317073170732
# key is  ADP  value  53  frequency  0.12926829268292683
# key is  SCONJ  value  12  frequency  0.02926829268292683
# key is  VERB  value  62  frequency  0.15121951219512195
# key is  AUX  value  22  frequency  0.05365853658536585
# key is  PART  value  26  frequency  0.06341463414634146
# key is  CCONJ  value  19  frequency  0.046341463414634146
# key is  ADJ  value  37  frequency  0.09024390243902439
# key is  PUNCT  value  40  frequency  0.0975609756097561
# key is  NUM  value  5  frequency  0.012195121951219513
# key is  PRON  value  16  frequency  0.03902439024390244
# key is  ADV  value  23  frequency  0.05609756097560976

# %%
t=True
while t:
    ch=input('press e if you want to stop')
    if ch == 'e':
        break
    filename = input('Enter a filename: ')
    with open('input/'+filename, 'r') as file:
        data = file.read()
    tag_freq(data)
# Out:
# =====tag FREQUENCY=====
# key is  DET  value  47  frequency  0.11463414634146342
# key is  NOUN  value  89  frequency  0.21707317073170732
# key is  ADP  value  53  frequency  0.12926829268292683
# key is  SCONJ  value  12  frequency  0.02926829268292683
# key is  VERB  value  62  frequency  0.15121951219512195
# key is  AUX  value  22  frequency  0.05365853658536585
# key is  PART  value  26  frequency  0.06341463414634146
# key is  CCONJ  value  19  frequency  0.046341463414634146
# key is  ADJ  value  37  frequency  0.09024390243902439
# key is  PUNCT  value  40  frequency  0.0975609756097561
# key is  NUM  value  5  frequency  0.012195121951219513
# key is  PRON  value  16  frequency  0.03902439024390244
# key is  ADV  value  23  frequency  0.05609756097560976

# %%
def word_cnt(str1):
    words=str1.split()
    return len(words)
w_l=word_cnt(data)
for key in tag_freq:
        #print("hi")
        if key=='NOUN':
            n=tag_freq[key]/w_l
        elif key == 'VERB':
            v=tag_freq[key]/w_l
        elif key =='ADJ':
            a=tag_freq[key]/w_l
        elif key =='PRON':
            p=tag_freq[key]/w_l
print(n,v,a,p)
# Out:
# 0.21707317073170732 0.15121951219512195 0.09024390243902439 0.03902439024390244

# %%
t=True
while t:
    ch=input('press e if you want to stop')
    if ch == 'e':
        break
    filename = input('Enter a filename: ')
    with open('human/'+filename, 'r') as file:
        data = file.read()
    tag_freq(data)

# %% [markdown]
# depency parsing

# %%
filename = input('Enter a filename: ')
with open('human/'+filename, 'r') as file:
 data = file.read()
data=" ".join(data.split())
text = nlp(data)
sent_tokenize = (list(text.sents))
for sent in sent_tokenize:
    #doc=nlp(sent)
    displacy.render(sent, style="dep")
    ch=input("press enter to continue")
    if ch=='e' or ch=='E':
        break
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="149cf7700b80443c9287ca8fe43beff8-0" class="displacy" width="4250" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">debate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
# ...

# %%
filename = input('Enter a filename: ')
with open('input/'+filename, 'r') as file:
 data1 = file.read()

text1 = nlp(data1)
sent_tokenize1 = (list(text1.sents))
for sent1 in sent_tokenize1:
    #doc=nlp(sent)
    displacy.render(sent1, style="dep")
    ch=input("press enter to continue")
    if ch=='e' or ch=='E':
        break
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b537600188024db5b378727349684c7a-0" class="displacy" width="2325" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">It</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
# ...

# %%
# !jupyter nbconvert --to pdf pos.ipynb
# Out:
# [NbConvertApp] Converting notebook pos.ipynb to pdf
# [NbConvertApp] Writing 26693 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# Traceback (most recent call last):
#   File "/opt/conda/bin/jupyter-nbconvert", line 11, in <module>
#     sys.exit(main())
#   File "/opt/conda/lib/python3.7/site-packages/jupyter_core/application.py", line 266, in launch_instance
#     return super(JupyterApp, cls).launch_instance(argv=argv, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/opt/conda/lib/python3.7/site-packages/nbconvert/nbconvertapp.py", line 337, in start
#     self.convert_notebooks()
#   File "/opt/conda/lib/python3.7/site-packages/nbconvert/nbconvertapp.py", line 507, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "/opt/conda/lib/python3.7/site-packages/nbconvert/nbconvertapp.py", line 478, in convert_single_notebook
# ...

# %%
# !conda activate es_env
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# If your shell is Bash or a Bourne variant, enable conda for the current user with
#
#     $ echo ". /opt/conda/etc/profile.d/conda.sh" >> ~/.bashrc
#
# or, for all users, enable conda with
#
#     $ sudo ln -s /opt/conda/etc/profile.d/conda.sh /etc/profile.d/conda.sh
#
# The options above will permanently enable the 'conda' command, but they do NOT
# put conda's base (root) environment on PATH.  To do so, run
#
#     $ conda activate
#
# in your terminal, or to put the base environment on PATH permanently, run
#
#     $ echo "conda activate" >> ~/.bashrc
#
# Previous to conda 4.4, the recommended way to activate conda was to modify PATH in
# your ~/.bashrc file.  You should manually remove the line that looks like
#
#     export PATH="/opt/conda/bin:$PATH"
#
# ^^^ The above line should NO LONGER be in your ~/.bashrc file! ^^^
