# %% [markdown]
# # this is with  Wilcoxon-ranksum

# %%
import pandas as pd

# Read the csv file
data1 = pd.read_csv('combined_3.csv')

# %%
df = data1.sample(frac = 1)

# %%
data2=pd.DataFrame()
data2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#col=['para_count', 'word_count', 'sentence_count', 'sentence_len(mean)', 'sentence_len(max)', 'sw_rates', 'unique_words', 'unique_words_rates', 'noun', 'verb', 'adj', 'pron', 'occurrance_of_most_freq_word', 'rate_of_occurrance', 'number_of_repeatation', 'max_occurance_of_most_frequent_phrase', 'avg sentence complexity', 'lexical diversity', 'word_sim_p_count', 'word_sim_p_score', 'word_sim_n_count', 'word_sim_n_score', 'word_sim_score', 'flesch grade', 'Automated Readability', 'coleman_liau', 'positive_sentiment', 'neutral_sentiment', 'discourse_marker', 'grammar','label']
col=['para_count', 'word_count', 'sentence_count', 'sentence_len(mean)', 'sentence_len(max)', 'avg_stop_word', 'unique_words', 'noun', 'verb', 'adj', 'pron', 'occurrance_of_most_freq_word', 'rate_of_occurrance', 'avg sentence complexity', 'lexical diversity', 'word_sim_p_count', 'word_sim_p_score', 'word_sim_n_count', 'word_sim_n_score', 'word_sim_score', 'flesch grade', 'Automated Readability', 'coleman_liau', 'positive_sentiment', 'neutral_sentiment', 'discourse_marker', 'grammar', 'sw_rate', 'sum_repeated_ngrams', 'count_repeated_ngrams', 'max_occurrence_ngrams','label']
data2[col]=df[col]

# %%
data2

# %%
from pycaret.classification import *

# %%
clf = setup(data = data2, target='label')
# Out:
# <style type="text/css">
# #T_334f2_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_334f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_334f2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_334f2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_334f2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_334f2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_334f2_row0_col1" class="data row0 col1" >478</td>
#     </tr>
#     <tr>
#       <th id="T_334f2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_334f2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_334f2_row1_col1" class="data row1 col1" >label</td>
#     </tr>
#     <tr>
#       <th id="T_334f2_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best=compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .             22:22:35
# Status     . . . . . . . . . . . . . . . . . .     Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Logistic Regression
# <style type="text/css">
# #T_f8f77 th {
#   text-align: left;
# }
# ...
